# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df_gd= pd.read_csv('C:/Users/kaany/Desktop/Uni Shit/YTU/3rd Semester/BLM2642/imageClassification/imageClassification/gd_stats.csv')

df_sgd = pd.read_csv('C:/Users/kaany/Desktop/Uni Shit/YTU/3rd Semester/BLM2642/imageClassification/imageClassification/sgd_stats.csv')

df_adam = pd.read_csv('C:/Users/kaany/Desktop/Uni Shit/YTU/3rd Semester/BLM2642/imageClassification/imageClassification/adam_stats.csv')

# %%
plot_gd_time = sns.lineplot(data=df_gd, x='time', y='test_mse')
plot_gd_time.set_title('Gradient Descent 0')
plot_gd_time.set(xlabel='Time', ylabel='Loss')
# Out:
# [Text(0.5, 0, 'Time'), Text(0, 0.5, 'Loss')]

# %%
plot_gd_time = sns.lineplot(data=df_gd, x='time', y='test_acc')
plot_gd_time.set_title('Gradient Descent 0')
plot_gd_time.set(xlabel='Time', ylabel='Accuracy%')
# Out:
# [Text(0.5, 0, 'Time'), Text(0, 0.5, 'Accuracy%')]

# %%
plot_gd_iter = sns.lineplot(data=df_gd, x='iter', y='test_mse')
plot_gd_iter.set_title('Gradient Descent 0')
plot_gd_iter.set(xlabel='Iteration count', ylabel='Loss')
# Out:
# [Text(0.5, 0, 'Iteration count'), Text(0, 0.5, 'Loss')]

# %%
plot_gd_iter = sns.lineplot(data=df_gd, x='iter', y='test_acc')
plot_gd_iter.set_title('Gradient Descent 0')
plot_gd_iter.set(xlabel='Iteration count', ylabel='Accuracy%')
# Out:
# [Text(0.5, 0, 'Iteration count'), Text(0, 0.5, 'Accuracy%')]

# %%
plot_sgd_time = sns.lineplot(data=df_sgd, x='time', y='test_mse')
plot_sgd_time.set_title('Stochastic Gradient Descent 0')
plot_sgd_time.set(xlabel='Time', ylabel='Loss')
# Out:
# [Text(0.5, 0, 'Time'), Text(0, 0.5, 'Loss')]

# %%
plot_sgd_time = sns.lineplot(data=df_sgd, x='time', y='test_acc')
plot_sgd_time.set_title('Stochastic Gradient Descent 0')
plot_sgd_time.set(xlabel='Time', ylabel='Accuracy%')
# Out:
# [Text(0.5, 0, 'Time'), Text(0, 0.5, 'Accuracy%')]

# %%
plot_sgd_iter = sns.lineplot(data=df_sgd, x='iter', y='test_mse')
plot_sgd_iter.set_title('Stochastic Gradient Descent 0')
plot_sgd_iter.set(xlabel='Iteration count', ylabel='Loss')
# Out:
# [Text(0.5, 0, 'Iteration count'), Text(0, 0.5, 'Loss')]

# %%
plot_sgd_iter = sns.lineplot(data=df_sgd, x='iter', y='test_acc')
plot_sgd_iter.set_title('Stochastic Gradient Descent 0')
plot_sgd_iter.set(xlabel='Iteration count', ylabel='Accracy%')
# Out:
# [Text(0.5, 0, 'Iteration count'), Text(0, 0.5, 'Accracy%')]

# %%
plot_adam_time = sns.lineplot(data=df_adam, x='time', y='test_mse')
plot_adam_time.set_title('ADAM 0')
plot_adam_time.set(xlabel='Time', ylabel='Loss')
# Out:
# [Text(0.5, 0, 'Time'), Text(0, 0.5, 'Loss')]

# %%
plot_adam_time = sns.lineplot(data=df_adam, x='time', y='test_acc')
plot_adam_time.set_title('ADAM 0')
plot_adam_time.set(xlabel='Time', ylabel='Accuracy%')
# Out:
# [Text(0.5, 0, 'Time'), Text(0, 0.5, 'Accuracy%')]

# %%
plot_adam_iter = sns.lineplot(data=df_adam, x='iter', y='test_mse')
plot_adam_iter.set_title('ADAM 0')
plot_adam_iter.set(xlabel='Iteration count', ylabel='Loss')
# Out:
# [Text(0.5, 0, 'Iteration count'), Text(0, 0.5, 'Loss')]

# %%
plot_adam_iter = sns.lineplot(data=df_adam, x='iter', y='test_acc')
plot_adam_iter.set_title('ADAM 0')
plot_adam_iter.set(xlabel='Iteration count', ylabel='Accuracy%')
# Out:
# [Text(0.5, 0, 'Iteration count'), Text(0, 0.5, 'Accuracy%')]
